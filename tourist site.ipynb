# %%
from tkinter import *
from PIL import ImageTk,Image
from tkinter.ttk import Combobox
from tkinter import messagebox

root=Tk()
root.title('Tourism India')
c1=Canvas(root,width=1000,height=650)
i1=ImageTk.PhotoImage(Image.open(r"t1.jpg"))
c1.create_image(0,0,anchor=NW,image=i1)
c1.grid()

l1=Label(c1,text='Welcome to Indian Tourism',fg='red',bg='light green',font=('times new roman',20,'bold'))
l1.place(x=200,y=40,width=600,height=50)

def f1():
    
    root1=Toplevel()
    c2=Canvas(root1,width=400,height=400)
    i2=ImageTk.PhotoImage(Image.open(r"haridwar.jpg"))
    c2.create_image(0,0,anchor=NW,image=i2)
    c2.grid(row=0,column=0)
    def hello():
        root2=Toplevel()
        root2.configure(bg='ivory')
        root2.title('Welcome to Haridwar tourism')
        
        d1=Canvas(root2,width=500,height=340)
        i11=ImageTk.PhotoImage(Image.open(r"h1.webp"))
        d1.create_image(0,0,anchor=NW,image=i11)
        d1.grid(row=0,column=1)
        
        def hello1():
            root3=Toplevel()
            def hello2():
                if(combo.get()=="paytm"):
                    messagebox.showinfo("information","your paytm payment is successful")
                elif(combo.get()=="google pay"):
                    messagebox.showinfo("information","your google pay payment is successful")
                elif(combo.get()=="mobile wallet"):
                    messagebox.showinfo("information","your mobile wallet payment is successful")
                elif(combo.get()=="cash mode"):
                    messagebox.showinfo("information"," you have to pay by visting office")
                    
                    
            l2=Label(root3,text='your payment will be'    +   str('10,000'),font=('times new roman',13))
            l2.grid()
            l3=Label(root3,text='choose your payment mode',font=('times new roman',13))
            l3.grid(row=2)
            combo=Combobox(root3,values=['cash mode','paytm','google pay','mobile wallet'])
            combo.grid(row=2,column=1)
            
            btn1=Button(root3,text="payment done",fg='green',command=hello2)
            btn1.grid(row=3,column=1)
    
            
            
        bt1=Button(root2,text='Traditional places',fg='red',bg='light green',font=('times new roman',10),command=hello1)
        bt1.grid(row=1,column=1)
        
        d2=Canvas(root2,width=500,height=340)
        i12=ImageTk.PhotoImage(Image.open(r"h2.jpg"))
        d2.create_image(0,0,anchor=NW,image=i12)
        d2.grid(row=0,column=2)
        
        def hi1():
            root4=Toplevel()
            def hi2():
                if(combo1.get()=="paytm"):
                    messagebox.showinfo("information","your paytm payment is successful")
                elif(combo1.get()=="google pay"):
                    messagebox.showinfo("information","your google pay payment is successful")
                elif(combo1.get()=="mobile wallet"):
                    messagebox.showinfo("information","your mobile wallet payment is successful")
                elif(combo1.get()=="cash mode"):
                    messagebox.showinfo("information"," you have to pay by visting office")
                    
                    
            l2=Label(root4,text='your payment will be'    +   str('12,000'),font=('times new roman',13))
            l2.grid()
            l3=Label(root4,text='choose your payment mode',font=('times new roman',13))
            l3.grid(row=2)
            combo1=Combobox(root4,values=['cash mode','paytm','google pay','mobile wallet'])
            combo1.grid(row=2,column=1)
            
            btn1=Button(root4,text="payment done",fg='green',command=hi2)
            btn1.grid(row=3,column=1)
            
    
        bt2=Button(root2,text='Adventure',fg='red',bg='light green',font=('times new roman',10),command=hi1)
        bt2.grid(row=1,column=2)
        
        d3=Canvas(root2,width=500,height=340)
        i13=ImageTk.PhotoImage(Image.open(r"hd4.jpg"))
        d3.create_image(0,0,anchor=NW,image=i13)
        d3.grid(row=3,column=2)
        
        def hmm1():
            root5=Toplevel()
            def hmm2():
                if(combo2.get()=="paytm"):
                    messagebox.showinfo("information","your paytm payment is successful")
                elif(combo2.get()=="google pay"):
                    messagebox.showinfo("information","your google pay payment is successful")
                elif(combo2.get()=="mobile wallet"):
                    messagebox.showinfo("information","your mobile wallet payment is successful")
                elif(combo2.get()=="cash mode"):
                    messagebox.showinfo("information"," you have to pay by visting office")
                    
                    
            l2=Label(root5,text='your payment will be'    +   str('70,000'),font=('times new roman',13))
            l2.grid()
            l3=Label(root5,text='choose your payment mode',font=('times new roman',13))
            l3.grid(row=2)
            combo2=Combobox(root5,values=['cash mode','paytm','google pay','mobile wallet'])
            combo2.grid(row=2,column=1)
            
            btn1=Button(root5,text="payment done",fg='green',command=hmm2)
            btn1.grid(row=3,column=1)
            
        
        bt3=Button(root2,text='Package includes all',fg='red',bg='light green',font=('times new roman',10),command=hmm1)
        bt3.grid(row=4,column=2)
        
        d4=Canvas(root2,width=500,height=340)
        i14=ImageTk.PhotoImage(Image.open(r"hd3.png"))
        d4.create_image(0,0,anchor=NW,image=i14)
        d4.grid(row=3,column=1)
        
        def hm1():
            root13=Toplevel()
            def hm2():
                if(combo2.get()=="paytm"):
                    messagebox.showinfo("information","your paytm payment is successful")
                elif(combo2.get()=="google pay"):
                    messagebox.showinfo("information","your google pay payment is successful")
                elif(combo2.get()=="mobile wallet"):
                    messagebox.showinfo("information","your mobile wallet payment is successful")
                elif(combo2.get()=="cash mode"):
                    messagebox.showinfo("information"," you have to pay by visting office")
                    
                    
            l2=Label(root13,text='your payment will be'    +   str('50,000'),font=('times new roman',13))
            l2.grid()
            l3=Label(root13,text='choose your payment mode',font=('times new roman',13))
            l3.grid(row=2)
            combo2=Combobox(root13,values=['cash mode','paytm','google pay','mobile wallet'])
            combo2.grid(row=2,column=1)
            
            btn1=Button(root13,text="payment done",fg='green',command=hm2)
            btn1.grid(row=3,column=1)
            
        
        bt3=Button(root2,text='yatra',fg='red',bg='light green',font=('times new roman',10),command=hm1)
        bt3.grid(row=4,column=1)
        
        
        
        root2.mainloop()
    
    b2=Button(root1,text='Haridwar',fg='red',bg='light green',font=('times new roman',10),command=hello)
    b2.grid(row=0,column=0)
    
    
    c3=Canvas(root1,width=400,height=400)
    i3=ImageTk.PhotoImage(Image.open(r"hyderabad.jpeg"))
    c3.create_image(0,0,anchor=NW,image=i3)
    c3.grid(row=0,column=2)
    
    def okay():
        root6=Toplevel()
        root6.title('Welcome to Hyderabad tourism')
        root6.configure(bg='ivory')
        d1=Canvas(root6,width=450,height=300)
        i11=ImageTk.PhotoImage(Image.open(r"hyd1.jpg"))
        d1.create_image(0,0,anchor=NW,image=i11)
        d1.grid(row=0,column=1)
        
        def okay1():
            root7=Toplevel()
            def okay2():
                if(combo.get()=="paytm"):
                    messagebox.showinfo("information","your paytm payment is successful")
                elif(combo.get()=="google pay"):
                    messagebox.showinfo("information","your google pay payment is successful")
                elif(combo.get()=="mobile wallet"):
                    messagebox.showinfo("information","your mobile wallet payment is successful")
                elif(combo.get()=="cash mode"):
                    messagebox.showinfo("information"," you have to pay by visting office")
                    
                    
            l2=Label(root7,text='your payment will be'    +    str('40,000'),font=('times new roman',13))
            l2.grid()
            l3=Label(root7,text='choose your payment mode',font=('times new roman',13))
            l3.grid(row=2)
            combo=Combobox(root7,values=['cash mode','paytm','google pay','mobile wallet'])
            combo.grid(row=2,column=1)
            
            btn1=Button(root7,text="payment done",fg='green',command=okay2)
            btn1.grid(row=3,column=1)
    
            
            
        bt1=Button(root6,text='Tourist places',fg='red',bg='light green',font=('times new roman',10),command=okay1)
        bt1.grid(row=1,column=1)
        
        d2=Canvas(root6,width=500,height=300)
        i12=ImageTk.PhotoImage(Image.open(r"hy2.jpg"))
        d2.create_image(0,0,anchor=NW,image=i12)
        d2.grid(row=0,column=2)
        
        def ok1():
            root8=Toplevel()
            def ok2():
                if(combo1.get()=="paytm"):
                    messagebox.showinfo("information","your paytm payment is successful")
                elif(combo1.get()=="google pay"):
                    messagebox.showinfo("information","your google pay payment is successful")
                elif(combo1.get()=="mobile wallet"):
                    messagebox.showinfo("information","your mobile wallet payment is successful")
                elif(combo1.get()=="cash mode"):
                    messagebox.showinfo("information"," you have to pay by visting office")
                    
                    
            l2=Label(root8,text='your payment will be'    +    str('30,000'),font=('times new roman',13))
            l2.grid()
            l3=Label(root8,text='choose your payment mode',font=('times new roman',13))
            l3.grid(row=2)
            combo1=Combobox(root8,values=['cash mode','paytm','google pay','mobile wallet'])
            combo1.grid(row=2,column=1)
            
            btn1=Button(root8,text="payment done",fg='green',command=ok2)
            btn1.grid(row=3,column=1)
            
    
        bt2=Button(root6,text='Srisailam',fg='red',bg='light green',font=('times new roman',10),command=ok1)
        bt2.grid(row=1,column=2)
        
        d3=Canvas(root6,width=400,height=300)
        i13=ImageTk.PhotoImage(Image.open(r"hyd2.jpg"))
        d3.create_image(0,0,anchor=NW,image=i13)
        d3.grid(row=0,column=3)
        
        def ote1():
            root9=Toplevel()
            def ote2():
                if(combo2.get()=="paytm"):
                    messagebox.showinfo("information","your paytm payment is successful")
                elif(combo2.get()=="google pay"):
                    messagebox.showinfo("information","your google pay payment is successful")
                elif(combo2.get()=="mobile wallet"):
                    messagebox.showinfo("information","your mobile wallet payment is successful")
                elif(combo2.get()=="cash mode"):
                    messagebox.showinfo("information"," you have to pay by visting office")
                    
                    
            l2=Label(root9,text='your payment will be'    +   str('60,000'),font=('times new roman',13))
            l2.grid()
            l3=Label(root9,text='choose your payment mode',font=('times new roman',13))
            l3.grid(row=2)
            combo2=Combobox(root9,values=['cash mode','paytm','google pay','mobile wallet'])
            combo2.grid(row=2,column=1)
            
            btn1=Button(root9,text="payment done",fg='green',command=ote2)
            btn1.grid(row=3,column=1)
            
        
        bt3=Button(root6,text='Package icludes all',fg='red',bg='light green',font=('times new roman',10),command=ote1)
        bt3.grid(row=1,column=3)
        
        

        root6.mainloop()
    
    b3=Button(root1,text='Hyderabad',fg='red',bg='light green',font=('times new roman',10),command=okay)
    b3.grid(row=0,column=2)
    
    c4=Canvas(root1,width=400,height=300)
    i4=ImageTk.PhotoImage(Image.open(r"goa.jpg"))
    c4.create_image(0,0,anchor=NW,image=i4)
    c4.grid(row=2,column=0)
    
    def go():
        root10=Toplevel()
        root10.configure(bg='ivory')
        root10.title('Welcome to Goa tourism')
        
        d1=Canvas(root10,width=700,height=300)
        i111=ImageTk.PhotoImage(Image.open(r"g2.jpg"))
        d1.create_image(0,0,anchor=NW,image=i111)
        d1.grid(row=3,column=0)
        
        def go1():
            root11=Toplevel()
            def go2():
                if(combo.get()=="paytm"):
                    messagebox.showinfo("information","your paytm payment is successful")
                elif(combo.get()=="google pay"):
                    messagebox.showinfo("information","your google pay payment is successful")
                elif(combo.get()=="mobile wallet"):
                    messagebox.showinfo("information","your mobile wallet payment is successful")
                elif(combo.get()=="cash mode"):
                    messagebox.showinfo("information"," you have to pay by visting office")
                    
                    
            l2=Label(root11,text='your payment will be'    +    str('35,000'),font=('times new roman',13))
            l2.grid()
            l3=Label(root11,text='choose your payment mode',font=('times new roman',13))
            l3.grid(row=2)
            combo=Combobox(root11,values=['cash mode','paytm','google pay','mobile wallet'])
            combo.grid(row=2,column=1)
            
            btn1=Button(root11,text="payment done",fg='green',command=go2)
            btn1.grid(row=3,column=1)
    
            
            
        bt1=Button(root10,text='Goa culture and stay only',fg='red',bg='light green',font=('times new roman',10),command=go1)
        bt1.grid(row=4,column=0)


        d2=Canvas(root10,width=700,height=400)
        i12=ImageTk.PhotoImage(Image.open(r"goa3.jpg"))
        d2.create_image(0,0,anchor=NW,image=i12)
        d2.grid(row=0,column=0)
        
        def goa1():
            root12=Toplevel()
            def goa2():
                if(combo1.get()=="paytm"):
                    messagebox.showinfo("information","your paytm payment is successful")
                elif(combo1.get()=="google pay"):
                    messagebox.showinfo("information","your google pay payment is successful")
                elif(combo1.get()=="mobile wallet"):
                    messagebox.showinfo("information","your mobile wallet payment is successful")
                elif(combo1.get()=="cash mode"):
                    messagebox.showinfo("information"," you have to pay by visting office")
                    
                    
            l2=Label(root12,text='your payment will be'    +    str('60,000'),font=('times new roman',13))
            l2.grid()
            l3=Label(root12,text='choose your payment mode',font=('times new roman',13))
            l3.grid(row=2)
            combo1=Combobox(root12,values=['cash mode','paytm','google pay','mobile wallet'])
            combo1.grid(row=2,column=1)
            
            btn1=Button(root12,text="payment done",fg='green',command=goa2)
            btn1.grid(row=3,column=1)
            
    
        bt2=Button(root10,text='Overall package',fg='red',bg='light green',font=('times new roman',10),command=goa1)
        bt2.grid(row=2,column=0)
        
        root10.mainloop()
    
    b4=Button(root1,text='Goa',fg='red',bg='light green',font=('times new roman',10),command=go)
    b4.grid(row=2,column=0)

    c5=Canvas(root1,width=400,height=300)
    i5=ImageTk.PhotoImage(Image.open(r"delhi11.webp"))
    c5.create_image(0,0,anchor=NW,image=i5)
    c5.grid(row=2,column=2)
    
    def de():
        root14=Toplevel()
        root14.configure(bg='ivory')
        root14.title('Welcome to Delhi tourism')
        
        d1=Canvas(root14,width=600,height=340)
        i11=ImageTk.PhotoImage(Image.open(r"d4.jpg"))
        d1.create_image(0,0,anchor=NW,image=i11)
        d1.grid(row=0,column=1)
        
        def de1():
            root15=Toplevel()
            def de2():
                if(combo.get()=="paytm"):
                    messagebox.showinfo("information","your paytm payment is successful")
                elif(combo.get()=="google pay"):
                    messagebox.showinfo("information","your google pay payment is successful")
                elif(combo.get()=="mobile wallet"):
                    messagebox.showinfo("information","your mobile wallet payment is successful")
                elif(combo.get()=="cash mode"):
                    messagebox.showinfo("information"," you have to pay by visting office")
                    
                    
            l2=Label(root15,text='your payment will be'    +   str('30,000'),font=('times new roman',13))
            l2.grid()
            l3=Label(root15,text='choose your payment mode',font=('times new roman',13))
            l3.grid(row=2)
            combo=Combobox(root15,values=['cash mode','paytm','google pay','mobile wallet'])
            combo.grid(row=2,column=1)
            
            btn1=Button(root15,text="payment done",fg='green',command=de2)
            btn1.grid(row=3,column=1)
    
            
            
        bt1=Button(root14,text='Delhi Darshan',fg='red',bg='light green',font=('times new roman',10),command=de1)
        bt1.grid(row=1,column=1)

        d2=Canvas(root14,width=600,height=340)
        i12=ImageTk.PhotoImage(Image.open(r"d5.jpg"))
        d2.create_image(0,0,anchor=NW,image=i12)
        d2.grid(row=0,column=2)
        
        def del1():
            root16=Toplevel()
            def del2():
                if(combo1.get()=="paytm"):
                    messagebox.showinfo("information","your paytm payment is successful")
                elif(combo1.get()=="google pay"):
                    messagebox.showinfo("information","your google pay payment is successful")
                elif(combo1.get()=="mobile wallet"):
                    messagebox.showinfo("information","your mobile wallet payment is successful")
                elif(combo1.get()=="cash mode"):
                    messagebox.showinfo("information"," you have to pay by visting office")
                    
                    
            l2=Label(root16,text='your payment will be'    +   str('10,000'),font=('times new roman',13))
            l2.grid()
            l3=Label(root16,text='choose your payment mode',font=('times new roman',13))
            l3.grid(row=2)
            combo1=Combobox(root16,values=['cash mode','paytm','google pay','mobile wallet'])
            combo1.grid(row=2,column=1)
            
            btn1=Button(root16,text="payment done",fg='green',command=del2)
            btn1.grid(row=3,column=1)
            
    
        bt2=Button(root14,text='Educational tour',fg='red',bg='light green',font=('times new roman',10),command=del1)
        bt2.grid(row=1,column=2)
        
        d3=Canvas(root14,width=600,height=340)
        i13=ImageTk.PhotoImage(Image.open(r"s2.jpg"))
        d3.create_image(0,0,anchor=NW,image=i13)
        d3.grid(row=3,column=1)
        
        def delh1():
            root17=Toplevel()
            def delh2():
                if(combo2.get()=="paytm"):
                    messagebox.showinfo("information","your paytm payment is successful")
                elif(combo2.get()=="google pay"):
                    messagebox.showinfo("information","your google pay payment is successful")
                elif(combo2.get()=="mobile wallet"):
                    messagebox.showinfo("information","your mobile wallet payment is successful")
                elif(combo2.get()=="cash mode"):
                    messagebox.showinfo("information"," you have to pay by visting office")
                    
                    
            l2=Label(root17,text='your payment will be'    +   str('40,000'),font=('times new roman',13))
            l2.grid()
            l3=Label(root17,text='choose your payment mode',font=('times new roman',13))
            l3.grid(row=2)
            combo2=Combobox(root17,values=['cash mode','paytm','google pay','mobile wallet'])
            combo2.grid(row=2,column=1)
            
            btn1=Button(root17,text="payment done",fg='green',command=delh2)
            btn1.grid(row=3,column=1)
            
        
        bt3=Button(root14,text='Gurugram & Sohna',fg='red',bg='light green',font=('times new roman',10),command=delh1)
        bt3.grid(row=4,column=1)
        
        d4=Canvas(root14,width=600,height=340)
        i14=ImageTk.PhotoImage(Image.open(r"delhi7.jpg"))
        d4.create_image(0,0,anchor=NW,image=i14)
        d4.grid(row=3,column=2)
        
        def delhi1():
            root18=Toplevel()
            def delhi2():
                if(combo2.get()=="paytm"):
                    messagebox.showinfo("information","your paytm payment is successful")
                elif(combo2.get()=="google pay"):
                    messagebox.showinfo("information","your google pay payment is successful")
                elif(combo2.get()=="mobile wallet"):
                    messagebox.showinfo("information","your mobile wallet payment is successful")
                elif(combo2.get()=="cash mode"):
                    messagebox.showinfo("information"," you have to pay by visting office")
                    
                    
            l2=Label(root18,text='your payment will be'    +   str('50,000'),font=('times new roman',13))
            l2.grid()
            l3=Label(root18,text='choose your payment mode',font=('times new roman',13))
            l3.grid(row=2)
            combo2=Combobox(root18,values=['cash mode','paytm','google pay','mobile wallet'])
            combo2.grid(row=2,column=1)
            
            btn1=Button(root18,text="payment done",fg='green',command=delhi2)
            btn1.grid(row=3,column=1)
            
        
        bt3=Button(root14,text='Delhi Events',fg='red',bg='light green',font=('times new roman',10),command=delhi1)
        bt3.grid(row=4,column=2)
        
        
        root14.mainloop()
    b5=Button(root1,text='Delhi',fg='red',bg='light green',font=('times new roman',10),command=de)
    b5.grid(row=2,column=2)

    c6=Canvas(root1,width=400,height=400)
    i6=ImageTk.PhotoImage(Image.open(r"chennai1.jpg"))
    c6.create_image(0,0,anchor=NW,image=i6)
    c6.grid(row=0,column=3)
    
    def ch():
        root19=Toplevel()
        root19.configure(bg='ivory')
        root19.title('Welcome to Chennai tourism')
        
        d1=Canvas(root19,width=600,height=300)
        i11=ImageTk.PhotoImage(Image.open(r"c1.jpg"))
        d1.create_image(0,0,anchor=NW,image=i11)
        d1.grid(row=0,column=1)
        
        def ch1():
            root20=Toplevel()
            def ch2():
                if(combo.get()=="paytm"):
                    messagebox.showinfo("information","your paytm payment is successful")
                elif(combo.get()=="google pay"):
                    messagebox.showinfo("information","your google pay payment is successful")
                elif(combo.get()=="mobile wallet"):
                    messagebox.showinfo("information","your mobile wallet payment is successful")
                elif(combo.get()=="cash mode"):
                    messagebox.showinfo("information"," you have to pay by visting office")
                    
                    
            l2=Label(root20,text='your payment will be'    +   str('40,000'),font=('times new roman',13))
            l2.grid()
            l3=Label(root20,text='choose your payment mode',font=('times new roman',13))
            l3.grid(row=2)
            combo=Combobox(root20,values=['cash mode','paytm','google pay','mobile wallet'])
            combo.grid(row=2,column=1)
            
            btn1=Button(root20,text="payment done",fg='green',command=ch2)
            btn1.grid(row=3,column=1)
    
            
            
        bt1=Button(root19,text='Chennai tourism',fg='red',bg='light green',font=('times new roman',10),command=ch1)
        bt1.grid(row=1,column=1)

        d2=Canvas(root19,width=600,height=300)
        i12=ImageTk.PhotoImage(Image.open(r"c2.jpg"))
        d2.create_image(0,0,anchor=NW,image=i12)
        d2.grid(row=0,column=2)
        
        def che1():
            root21=Toplevel()
            def che2():
                if(combo1.get()=="paytm"):
                    messagebox.showinfo("information","your paytm payment is successful")
                elif(combo1.get()=="google pay"):
                    messagebox.showinfo("information","your google pay payment is successful")
                elif(combo1.get()=="mobile wallet"):
                    messagebox.showinfo("information","your mobile wallet payment is successful")
                elif(combo1.get()=="cash mode"):
                    messagebox.showinfo("information"," you have to pay by visting office")
                    
                    
            l2=Label(root21,text='your payment will be'    +   str('45,000'),font=('times new roman',13))
            l2.grid()
            l3=Label(root21,text='choose your payment mode',font=('times new roman',13))
            l3.grid(row=2)
            combo1=Combobox(root21,values=['cash mode','paytm','google pay','mobile wallet'])
            combo1.grid(row=2,column=1)
            
            btn1=Button(root21,text="payment done",fg='green',command=che2)
            btn1.grid(row=3,column=1)
            
    
        bt2=Button(root19,text='Evoke with Tamil culture',fg='red',bg='light green',font=('times new roman',10),command=che1)
        bt2.grid(row=1,column=2)
        
        d3=Canvas(root19,width=600,height=340)
        i13=ImageTk.PhotoImage(Image.open(r"c3.jpg"))
        d3.create_image(0,0,anchor=NW,image=i13)
        d3.grid(row=3,column=1)
        
        def chen1():
            root22=Toplevel()
            def chen2():
                if(combo2.get()=="paytm"):
                    messagebox.showinfo("information","your paytm payment is successful")
                elif(combo2.get()=="google pay"):
                    messagebox.showinfo("information","your google pay payment is successful")
                elif(combo2.get()=="mobile wallet"):
                    messagebox.showinfo("information","your mobile wallet payment is successful")
                elif(combo2.get()=="cash mode"):
                    messagebox.showinfo("information"," you have to pay by visting office")
                    
                    
            l2=Label(root22,text='your payment will be'    +   str('50,000'),font=('times new roman',13))
            l2.grid()
            l3=Label(root22,text='choose your payment mode',font=('times new roman',13))
            l3.grid(row=2)
            combo2=Combobox(root22,values=['cash mode','paytm','google pay','mobile wallet'])
            combo2.grid(row=2,column=1)
            
            btn1=Button(root22,text="payment done",fg='green',command=chen2)
            btn1.grid(row=3,column=1)
            
        
        bt3=Button(root19,text='Trupati Balaji',fg='red',bg='light green',font=('times new roman',10),command=chen1)
        bt3.grid(row=4,column=1)
        
        d4=Canvas(root19,width=600,height=340)
        i14=ImageTk.PhotoImage(Image.open(r"c9.jpg"))
        d4.create_image(0,0,anchor=NW,image=i14)
        d4.grid(row=3,column=2)
        
        def chenn1():
            root23=Toplevel()
            def chenn2():
                if(combo2.get()=="paytm"):
                    messagebox.showinfo("information","your paytm payment is successful")
                elif(combo2.get()=="google pay"):
                    messagebox.showinfo("information","your google pay payment is successful")
                elif(combo2.get()=="mobile wallet"):
                    messagebox.showinfo("information","your mobile wallet payment is successful")
                elif(combo2.get()=="cash mode"):
                    messagebox.showinfo("information"," you have to pay by visting office")
                    
                    
            l2=Label(root23,text='your payment will be'    +   str('80,000'),font=('times new roman',13))
            l2.grid()
            l3=Label(root23,text='choose your payment mode',font=('times new roman',13))
            l3.grid(row=2)
            combo2=Combobox(root23,values=['cash mode','paytm','google pay','mobile wallet'])
            combo2.grid(row=2,column=1)
            
            btn1=Button(root23,text="payment done",fg='green',command=chenn2)
            btn1.grid(row=3,column=1)
            
        
        bt3=Button(root19,text='overall tourist package',fg='red',bg='light green',font=('times new roman',10),command=chenn1)
        bt3.grid(row=4,column=2)
        
        
        root19.mainloop()
    b6=Button(root1,text='chennai',fg='red',bg='light green',font=('times new roman',10),command=ch)
    b6.grid(row=0,column=3)
    
    
    c7=Canvas(root1,width=400,height=300)
    i7=ImageTk.PhotoImage(Image.open(r"chandigarh1.jpg"))
    c7.create_image(0,0,anchor=NW,image=i7)
    c7.grid(row=2,column=3)
    
    def t():
        root24=Toplevel()
        root24.configure(bg='ivory')
        root24.title('Welcome to Chandigarh tourism')
        
        d1=Canvas(root24,width=500,height=370)
        i11=ImageTk.PhotoImage(Image.open(r"p2.jpg"))
        d1.create_image(0,0,anchor=NW,image=i11)
        d1.grid(row=0,column=1)
        
        def t1():
            root25=Toplevel()
            def t2():
                if(combo.get()=="paytm"):
                    messagebox.showinfo("information","your paytm payment is successful")
                elif(combo.get()=="google pay"):
                    messagebox.showinfo("information","your google pay payment is successful")
                elif(combo.get()=="mobile wallet"):
                    messagebox.showinfo("information","your mobile wallet payment is successful")
                elif(combo.get()=="cash mode"):
                    messagebox.showinfo("information"," you have to pay by visting office")
                    
                    
            l2=Label(root25,text='your payment will be'    +   str('10,000'),font=('times new roman',13))
            l2.grid()
            l3=Label(root25,text='choose your payment mode',font=('times new roman',13))
            l3.grid(row=2)
            combo=Combobox(root25,values=['cash mode','paytm','google pay','mobile wallet'])
            combo.grid(row=2,column=1)
            
            btn1=Button(root25,text="payment done",fg='green',command=t2)
            btn1.grid(row=3,column=1)
    
              
        bt1=Button(root24,text='Chandigarh vist',fg='red',bg='light green',font=('times new roman',10),command=t1)
        bt1.grid(row=1,column=1)
        
        d2=Canvas(root24,width=600,height=370)
        i12=ImageTk.PhotoImage(Image.open(r"p3.jpg"))
        d2.create_image(0,0,anchor=NW,image=i12)
        d2.grid(row=0,column=2)
        
        def tr1():
            root26=Toplevel()
            def tr2():
                if(combo1.get()=="paytm"):
                    messagebox.showinfo("information","your paytm payment is successful")
                elif(combo1.get()=="google pay"):
                    messagebox.showinfo("information","your google pay payment is successful")
                elif(combo1.get()=="mobile wallet"):
                    messagebox.showinfo("information","your mobile wallet payment is successful")
                elif(combo1.get()=="cash mode"):
                    messagebox.showinfo("information"," you have to pay by visting office")
                    
                    
            l2=Label(root26,text='your payment will be'    +   str('15,000'),font=('times new roman',13))
            l2.grid()
            l3=Label(root26,text='choose your payment mode',font=('times new roman',13))
            l3.grid(row=2)
            combo1=Combobox(root26,values=['cash mode','paytm','google pay','mobile wallet'])
            combo1.grid(row=2,column=1)
            
            btn1=Button(root26,text="payment done",fg='green',command=tr2)
            btn1.grid(row=3,column=1)
            
    
        bt2=Button(root24,text='Rohini hills',fg='red',bg='light green',font=('times new roman',10),command=tr1)
        bt2.grid(row=1,column=2)
        
        d3=Canvas(root24,width=500,height=340)
        i13=ImageTk.PhotoImage(Image.open(r"p5.jpg"))
        d3.create_image(0,0,anchor=NW,image=i13)
        d3.grid(row=3,column=1)
        
        def tra1():
            root27=Toplevel()
            def tra2():
                if(combo2.get()=="paytm"):
                    messagebox.showinfo("information","your paytm payment is successful")
                elif(combo2.get()=="google pay"):
                    messagebox.showinfo("information","your google pay payment is successful")
                elif(combo2.get()=="mobile wallet"):
                    messagebox.showinfo("information","your mobile wallet payment is successful")
                elif(combo2.get()=="cash mode"):
                    messagebox.showinfo("information"," you have to pay by visting office")
                    
                    
            l2=Label(root27,text='your payment will be'    +   str('6,000'),font=('times new roman',13))
            l2.grid()
            l3=Label(root27,text='choose your payment mode',font=('times new roman',13))
            l3.grid(row=2)
            combo2=Combobox(root27,values=['cash mode','paytm','google pay','mobile wallet'])
            combo2.grid(row=2,column=1)
            
            btn1=Button(root27,text="payment done",fg='green',command=tra2)
            btn1.grid(row=3,column=1)
            
        
        bt3=Button(root24,text='Sector-34',fg='red',bg='light green',font=('times new roman',10),command=tra1)
        bt3.grid(row=4,column=1)
        
        d4=Canvas(root24,width=600,height=340)
        i14=ImageTk.PhotoImage(Image.open(r"p4.jpg"))
        d4.create_image(0,0,anchor=NW,image=i14)
        d4.grid(row=3,column=2)
        
        def trav1():
            root28=Toplevel()
            def trav2():
                if(combo2.get()=="paytm"):
                    messagebox.showinfo("information","your paytm payment is successful")
                elif(combo2.get()=="google pay"):
                    messagebox.showinfo("information","your google pay payment is successful")
                elif(combo2.get()=="mobile wallet"):
                    messagebox.showinfo("information","your mobile wallet payment is successful")
                elif(combo2.get()=="cash mode"):
                    messagebox.showinfo("information"," you have to pay by visting office")
                    
                    
            l2=Label(root28,text='your payment will be'    +   str('10,000'),font=('times new roman',13))
            l2.grid()
            l3=Label(root28,text='choose your payment mode',font=('times new roman',13))
            l3.grid(row=2)
            combo2=Combobox(root28,values=['cash mode','paytm','google pay','mobile wallet'])
            combo2.grid(row=2,column=1)
            
            btn1=Button(root28,text="payment done",fg='green',command=trav2)
            btn1.grid(row=3,column=1)
            
        
        bt3=Button(root24,text='Live concert',fg='red',bg='light green',font=('times new roman',10),command=trav1)
        bt3.grid(row=4,column=2)
        
        root24.mainloop()
        
    b7=Button(root1,text='chandigarh',fg='red',bg='light green',font=('times new roman',10),command=t)
    b7.grid(row=2,column=3)
    
    
    
    root1.mainloop()
    
    
b1=Button(c1,text='Click here to get dream places',fg='red',bg='light green',font=('times new roman',20,'bold'),command=f1)
b1.place(x=280,y=120,width=400,height=50)

root.mainloop()
